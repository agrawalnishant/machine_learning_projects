# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 32
patch_size = 5
depth = 32
num_hidden = 1024

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.01))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(0.01, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.01))
  layer3_biases = tf.Variable(tf.constant(0.01, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(0.01, shape=[num_labels]))

  def max_pool_2x2(x):
     return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],
                        strides=[1, 2, 2, 1], padding='SAME')
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    h_pool1 = max_pool_2x2(hidden)
    conv = tf.nn.conv2d(h_pool1, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    h_pool2 = max_pool_2x2(hidden)
    shape = h_pool2.get_shape().as_list()
    reshape = tf.reshape(h_pool2, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  global_step = tf.Variable(0, trainable=False)
  starter_learning_rate = 0.07
  learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step,
                                           1000, 0.99, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss,global_step=global_step)
    
  #optimizer = tf.train.GradientDescentOptimizer(0.08).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 50001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 500 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.306943
# Minibatch accuracy: 12.5%
# Validation accuracy: 15.6%
# Minibatch loss at step 500: 0.243118
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.8%
# Minibatch loss at step 1000: 0.257948
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.9%
# Minibatch loss at step 1500: 0.087835
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.8%
# Minibatch loss at step 2000: 0.158202
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.5%
# Minibatch loss at step 2500: 0.759075
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.3%
# Minibatch loss at step 3000: 0.168331
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.3%
# Minibatch loss at step 3500: 0.461241
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.6%
# Minibatch loss at step 4000: 0.203072
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.8%
# Minibatch loss at step 4500: 0.403473
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.7%
# Minibatch loss at step 5000: 0.363569
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.1%
# Minibatch loss at step 5500: 0.387728
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.1%
# Minibatch loss at step 6000: 0.358981
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.3%
# Minibatch loss at step 6500: 0.105348
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.4%
# Minibatch loss at step 7000: 0.599332
# Minibatch accuracy: 78.1%
# Validation accuracy: 91.5%
# Minibatch loss at step 7500: 0.230218
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.5%
# Minibatch loss at step 8000: 0.224301
# Minibatch accuracy: 100.0%
# Validation accuracy: 91.7%
# Minibatch loss at step 8500: 0.430039
# Minibatch accuracy: 81.2%
# Validation accuracy: 91.6%
# Minibatch loss at step 9000: 0.187534
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.7%
# Minibatch loss at step 9500: 0.362614
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.5%
# Minibatch loss at step 10000: 0.129260
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.9%
# Minibatch loss at step 10500: 0.169322
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.7%
# Minibatch loss at step 11000: 0.189006
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.1%
# Minibatch loss at step 11500: 0.009769
# Minibatch accuracy: 100.0%
# Validation accuracy: 91.8%
# Minibatch loss at step 12000: 0.193938
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.8%
# Minibatch loss at step 12500: 0.297658
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.2%
# Minibatch loss at step 13000: 0.029857
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.2%
# Minibatch loss at step 13500: 0.106210
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 14000: 0.226028
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.0%
# Minibatch loss at step 14500: 0.191143
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.8%
# Minibatch loss at step 15000: 0.240942
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.0%
# Minibatch loss at step 15500: 0.105893
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.1%
# Minibatch loss at step 16000: 0.121480
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.5%
# Minibatch loss at step 16500: 0.249259
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.8%
# Minibatch loss at step 17000: 0.104215
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.9%
# Minibatch loss at step 17500: 0.194901
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.1%
# Minibatch loss at step 18000: 0.246320
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.0%
# Minibatch loss at step 18500: 0.306687
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.8%
# Minibatch loss at step 19000: 0.264901
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.2%
# Minibatch loss at step 19500: 0.189851
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.4%
# Minibatch loss at step 20000: 0.038989
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 20500: 0.047515
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.1%
# Minibatch loss at step 21000: 0.285590
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.3%
# Minibatch loss at step 21500: 0.030996
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 22000: 0.106230
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.0%
# Minibatch loss at step 22500: 0.211504
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.4%
# Minibatch loss at step 23000: 0.006123
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 23500: 0.152763
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.3%
# Minibatch loss at step 24000: 0.024723
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 24500: 0.089014
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.0%
# Minibatch loss at step 25000: 0.122206
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.3%
# Minibatch loss at step 25500: 0.052539
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 26000: 0.134426
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.1%
# Minibatch loss at step 26500: 0.063836
# Minibatch accuracy: 100.0%
# Validation accuracy: 91.9%
# Minibatch loss at step 27000: 0.031308
# Minibatch accuracy: 100.0%
# Validation accuracy: 91.8%
# Minibatch loss at step 27500: 0.311056
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.8%
# Minibatch loss at step 28000: 0.002680
# Minibatch accuracy: 100.0%
# Validation accuracy: 91.9%
# Minibatch loss at step 28500: 0.062744
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.1%
# Minibatch loss at step 29000: 0.002416
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.0%
# Minibatch loss at step 29500: 0.122501
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.0%
# Minibatch loss at step 30000: 0.174019
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.3%
# Minibatch loss at step 30500: 0.068448
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.1%
# Minibatch loss at step 31000: 0.122035
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.5%
# Minibatch loss at step 31500: 0.006474
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 32000: 0.048454
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.2%
# Minibatch loss at step 32500: 0.013442
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.1%
# Minibatch loss at step 33000: 0.030643
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 33500: 0.080663
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 34000: 0.032494
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 34500: 0.058138
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.9%
# Minibatch loss at step 35000: 0.045290
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.0%
# Minibatch loss at step 35500: 0.042735
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 36000: 0.072323
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.1%
# Minibatch loss at step 36500: 0.012087
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 37000: 0.011559
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.0%
# Minibatch loss at step 37500: 0.001905
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 38000: 0.003130
# Minibatch accuracy: 100.0%
# Validation accuracy: 91.7%
# Minibatch loss at step 38500: 0.003465
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 39000: 0.077932
# Minibatch accuracy: 100.0%
# Validation accuracy: 91.6%
# Minibatch loss at step 39500: 0.071039
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.0%
# Minibatch loss at step 40000: 0.002747
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.0%
# Minibatch loss at step 40500: 0.003220
# Minibatch accuracy: 100.0%
# Validation accuracy: 91.9%
# Minibatch loss at step 41000: 0.028169
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 41500: 0.083980
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.9%
# Minibatch loss at step 42000: 0.123773
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.3%
# Minibatch loss at step 42500: 0.020670
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.0%
# Minibatch loss at step 43000: 0.002059
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 43500: 0.047833
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 44000: 0.028509
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.0%
# Minibatch loss at step 44500: 0.037216
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.5%
# Minibatch loss at step 45000: 0.104023
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.2%
# Minibatch loss at step 45500: 0.000747
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 46000: 0.007089
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.0%
# Minibatch loss at step 46500: 0.104254
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.2%
# Minibatch loss at step 47000: 0.014567
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.0%
# Minibatch loss at step 47500: 0.015252
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.4%
# Minibatch loss at step 48000: 0.048097
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 48500: 0.024740
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.4%
# Minibatch loss at step 49000: 0.101951
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.3%
# Minibatch loss at step 49500: 0.119385
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.2%
# Minibatch loss at step 50000: 0.067815
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.5%
# Test accuracy: 97.0%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---
